# %% [markdown]
# ## Ingesting data from Silver Layer

# %%
from pyspark.sql import functions as F
from pyspark.sql.functions import *
# Out:
# StatementMeta(, 182160f5-f81d-487b-aeae-4a71abfb9635, 11, Finished, Available, Finished)

# %%
#Reading data from silver table
silver_df = spark.read.format("delta").table("SilverLakehouse.silver_table")
# Out:
# StatementMeta(, 182160f5-f81d-487b-aeae-4a71abfb9635, 3, Finished, Available, Finished)

# %% [markdown]
# ## Analytical queries

# %%
# Query 1: Students who have not submitted Assignment_101

not_submitted_df = silver_df \
    .filter((col("AssignmentID") == "A101") & col("SubmissionID").isNull()) \
    .select("StudentID", "Name", "Email")

# Formatted JSON Output
not_submitted_result = {
    "status": "success",
    "message": "Students who have not submitted Assignment_101",
    "data": not_submitted_df.collect()
}

display(not_submitted_result)
# Out:
# StatementMeta(, 182160f5-f81d-487b-aeae-4a71abfb9635, 14, Finished, Available, Finished)
# {'status': 'success',
#  'message': 'Students who have not submitted Assignment_101',
#  'data': [Row(StudentID='S1089', Name='Anthony Everett', Email='ewilson@example.com'),
#   Row(StudentID='S1078', Name='Marie Gilbert', Email='umarshall@example.net'),
#   Row(StudentID='S1048', Name='Deborah Rodriguez', Email='yreed@example.com'),
#   Row(StudentID='S1071', Name='Marissa Webster', Email='jamessmith@example.org'),
#   Row(StudentID='S1059', Name='Justin Lowery', Email='bryantlaurie@example.net'),
#   Row(StudentID='S1015', Name='Valerie Gill', Email='harrellkenneth@example.net'),
#   Row(StudentID='S1072', Name='Michael Elliott', Email='stevenscott@example.com'),
#   Row(StudentID='S1007', Name='Daniel Adams', Email='lynchgeorge@example.net'),
#   Row(StudentID='S1000', Name='Allison Hill', Email='donaldgarcia@example.net'),
#   Row(StudentID='S1018', Name='Rose Spence', Email='davidalvarez@example.net'),
#   Row(StudentID='S1082', Name='Justin Allen', Email='fbrewer@example.com'),
#   Row(StudentID='S1087', Name='Michael Martinez', Email='mccannangela@example.net'),
#   Row(StudentID='S1014', Name='Martin Rodriguez', Email='amoore@example.net'),
#   Row(StudentID='S1053', Name='Joshua Smith', Email='jason99@example.net'),
#   Row(StudentID='S1086', Name='Paige Carlson', Email='wallkenneth@example.com'),
#   Row(StudentID='S1029', Name='Rachel Mitchell', Email='smoore@example.org'),
#   Row(StudentID='S1027', Name='Krista Williams', Email='novaksara@example.org'),
#   Row(StudentID='S1094', Name='Julie Johnson', Email='jasmine71@example.net'),
#   Row(StudentID='S1054', Name='Jeremy Lewis', Email='yleon@example.net'),
#   Row(StudentID='S1052', Name='Cameron Fisher', Email='lbyrd@example.net'),
#   Row(StudentID='S1004', Name='Ian Cooper', Email='lindsay78@example.org'),
#   Row(StudentID='S1035', Name='Daniel Baker', Email='nicole35@example.com'),
#   Row(StudentID='S1005', Name='Juan Calderon', Email='barbara10@example.net')]}

# %%
#Save dataframe to gold table
not_submitted_df.write.format("delta").mode("overwrite").saveAsTable("GoldLakehouse.gold_NotSubmitted")
# Out:
# StatementMeta(, 182160f5-f81d-487b-aeae-4a71abfb9635, 17, Finished, Available, Finished)

# %%
# Query 2: Submission rate per course (as a %)

# Total expected submissions per course
total_expected = silver_df.groupBy("CourseID", "CourseName").agg(count("*").alias("total_expected"))

# Actual submissions per course
actual_submissions = silver_df.filter(col("SubmissionID").isNotNull()) \
    .groupBy("CourseID").agg(count("*").alias("actual_submitted"))

# Join and calculate submission rate
submission_rate_df = total_expected.join(actual_submissions, "CourseID", "left") \
    .withColumn("actual_submitted", F.coalesce(col("actual_submitted"), lit(0))) \
    .withColumn("SubmissionRatePercent", round((col("actual_submitted") / col("total_expected")) * 100, 2)) \
    .select("CourseName", "SubmissionRatePercent")

# Format JSON Output
submission_rate_result = {
    "status": "success",
    "message": "Submission rate per course",
    "data": submission_rate_df.collect()
}

display(submission_rate_result)
# Out:
# StatementMeta(, 182160f5-f81d-487b-aeae-4a71abfb9635, 15, Finished, Available, Finished)
# {'status': 'success',
#  'message': 'Submission rate per course',
#  'data': [Row(CourseName='Business-focused demand-driven flexibility', SubmissionRatePercent=8.62),
#   Row(CourseName='Triple-buffered cohesive function', SubmissionRatePercent=11.36),
#   Row(CourseName='Managed incremental solution', SubmissionRatePercent=8.54),
#   Row(CourseName='Organic even-keeled contingency', SubmissionRatePercent=10.7),
#   Row(CourseName='Customizable maximized capability', SubmissionRatePercent=12.57),
#   Row(CourseName='Ergonomic multi-state hierarchy', SubmissionRatePercent=7.02),
#   Row(CourseName='Automated logistical array', SubmissionRatePercent=12.9),
#   Row(CourseName='Phased grid-enabled installation', SubmissionRatePercent=8.87)]}

# %%
#Save dataframe to gold table
submission_rate_df.write.format("delta").mode("overwrite").saveAsTable("GoldLakehouse.gold_SubmissionRate")
# Out:
# StatementMeta(, 182160f5-f81d-487b-aeae-4a71abfb9635, 18, Finished, Available, Finished)

# %%
# Query 3: Overdue assignment count per student

overdue_df = silver_df \
    .filter((col("SubmissionID").isNull()) & (col("DueDate") < current_date())) \
    .groupBy("StudentID", "Name") \
    .agg(count("*").alias("OverdueCount"))

# Format JSON Output
overdue_result = {
    "status": "success",
    "message": "Overdue assignment count per student",
    "data": overdue_df.collect()
}

display(overdue_result)
# Out:
# StatementMeta(, 182160f5-f81d-487b-aeae-4a71abfb9635, 16, Finished, Available, Finished)
# {'status': 'success',
#  'message': 'Overdue assignment count per student',
#  'data': [Row(StudentID='S1095', Name='Rachel Weber', OverdueCount=18),
#   Row(StudentID='S1038', Name='Grant Watts', OverdueCount=9),
#   Row(StudentID='S1076', Name='Joseph Stanley', OverdueCount=12),
#   Row(StudentID='S1078', Name='Marie Gilbert', OverdueCount=26),
#   Row(StudentID='S1061', Name='Scott Cole', OverdueCount=5),
#   Row(StudentID='S1005', Name='Juan Calderon', OverdueCount=16),
#   Row(StudentID='S1036', Name='Joshua Turner', OverdueCount=16),
#   Row(StudentID='S1020', Name='Jennifer Powers', OverdueCount=11),
#   Row(StudentID='S1045', Name='Ashley Brennan', OverdueCount=12),
#   Row(StudentID='S1071', Name='Marissa Webster', OverdueCount=17),
#   Row(StudentID='S1029', Name='Rachel Mitchell', OverdueCount=11),
#   Row(StudentID='S1023', Name='Carlos Walls', OverdueCount=11),
#   Row(StudentID='S1027', Name='Krista Williams', OverdueCount=17),
#   Row(StudentID='S1086', Name='Paige Carlson', OverdueCount=14),
#   Row(StudentID='S1092', Name='Wanda Torres', OverdueCount=6),
#   Row(StudentID='S1022', Name='Austin Johnson', OverdueCount=6),
#   Row(StudentID='S1003', Name='Melissa Peterson', OverdueCount=8),
#   Row(StudentID='S1069', Name='James Lewis', OverdueCount=14),
#   Row(StudentID='S1077', Name='Jeffrey Cox PhD', OverdueCount=7),
#   Row(StudentID='S1094', Name='Julie Johnson', OverdueCount=19),
#   Row(StudentID='S1050', Name='Kimberly Ball', OverdueCount=13),
#   Row(StudentID='S1093', Name='Matthew Moore', OverdueCount=5),
#   Row(StudentID='S1074', Name='Michael Rubio', OverdueCount=12),
#   Row(StudentID='S1042', Name='Valerie Williams', OverdueCount=5),
#   Row(StudentID='S1058', Name='Stephanie Dalton', OverdueCount=10),
#   Row(StudentID='S1028', Name='John Hancock', OverdueCount=8),
#   Row(StudentID='S1080', Name='Gabrielle Snyder', OverdueCount=8),
#   Row(StudentID='S1037', Name='Brandy Wilson', OverdueCount=17),
#   Row(StudentID='S1009', Name='Renee Morales', OverdueCount=8),
#   Row(StudentID='S1004', Name='Ian Cooper', OverdueCount=23),
#   Row(StudentID='S1052', Name='Cameron Fisher', OverdueCount=22),
#   Row(StudentID='S1048', Name='Deborah Rodriguez', OverdueCount=14),
#   Row(StudentID='S1000', Name='Allison Hill', OverdueCount=14),
#   Row(StudentID='S1051', Name='Erik Charles', OverdueCount=8),
#   Row(StudentID='S1063', Name='David Benson', OverdueCount=15),
#   Row(StudentID='S1081', Name='Kyle Beard', OverdueCount=5),
#   Row(StudentID='S1073', Name='Tracey Higgins', OverdueCount=5),
#   Row(StudentID='S1091', Name='Phillip Obrien', OverdueCount=7),
#   Row(StudentID='S1060', Name='Linda Dodson DVM', OverdueCount=17),
#   Row(StudentID='S1019', Name='Shane Henderson', OverdueCount=9),
#   Row(StudentID='S1070', Name='Julie Curry', OverdueCount=4),
#   Row(StudentID='S1097', Name='Caleb Barker', OverdueCount=10),
#   Row(StudentID='S1039', Name='Donald Smith', OverdueCount=22),
#   Row(StudentID='S1035', Name='Daniel Baker', OverdueCount=11),
#   Row(StudentID='S1025', Name='Maria Brown', OverdueCount=3),
#   Row(StudentID='S1034', Name='Eugene Walton', OverdueCount=5),
#   Row(StudentID='S1057', Name='Mark Lee', OverdueCount=6),
#   Row(StudentID='S1053', Name='Joshua Smith', OverdueCount=15),
#   Row(StudentID='S1006', Name='Victoria Wyatt', OverdueCount=8),
#   Row(StudentID='S1090', Name='Mark Brown', OverdueCount=8),
#   Row(StudentID='S1018', Name='Rose Spence', OverdueCount=7),
#   Row(StudentID='S1075', Name='Lori Garcia', OverdueCount=12),
#   Row(StudentID='S1056', Name='Alexander Sanchez', OverdueCount=20),
#   Row(StudentID='S1084', Name='Jessica Reese', OverdueCount=5),
#   Row(StudentID='S1083', Name='Edward Sullivan', OverdueCount=21),
#   Row(StudentID='S1082', Name='Justin Allen', OverdueCount=17),
#   Row(StudentID='S1007', Name='Daniel Adams', OverdueCount=13),
#   Row(StudentID='S1066', Name='Connie Robinson', OverdueCount=16),
#   Row(StudentID='S1031', Name='Jordan York', OverdueCount=8),
#   Row(StudentID='S1059', Name='Justin Lowery', OverdueCount=22),
#   Row(StudentID='S1064', Name='Daniel Fisher', OverdueCount=4),
#   Row(StudentID='S1098', Name='Kyle Preston', OverdueCount=7),
#   Row(StudentID='S1043', Name='Shelly Dickson', OverdueCount=2),
#   Row(StudentID='S1015', Name='Valerie Gill', OverdueCount=34),
#   Row(StudentID='S1087', Name='Michael Martinez', OverdueCount=16),
#   Row(StudentID='S1032', Name='Steve Sanchez', OverdueCount=2),
#   Row(StudentID='S1054', Name='Jeremy Lewis', OverdueCount=10),
#   Row(StudentID='S1030', Name='Kimberly Adkins', OverdueCount=11),
#   Row(StudentID='S1024', Name='Matthew Gomez', OverdueCount=11),
#   Row(StudentID='S1088', Name='Nicole Garcia', OverdueCount=16),
#   Row(StudentID='S1055', Name='Diane Beck', OverdueCount=7),
#   Row(StudentID='S1001', Name='Leslie Johnson', OverdueCount=14),
#   Row(StudentID='S1010', Name='Jonathan Wilkerson', OverdueCount=4),
#   Row(StudentID='S1021', Name='George Chapman', OverdueCount=8),
#   Row(StudentID='S1072', Name='Michael Elliott', OverdueCount=14),
#   Row(StudentID='S1014', Name='Martin Rodriguez', OverdueCount=11),
#   Row(StudentID='S1079', Name='David Michael', OverdueCount=15),
#   Row(StudentID='S1013', Name='Zachary Rice', OverdueCount=1),
#   Row(StudentID='S1089', Name='Anthony Everett', OverdueCount=19),
#   Row(StudentID='S1016', Name='Brittany Farmer', OverdueCount=12),
#   Row(StudentID='S1049', Name='Kayla Cruz', OverdueCount=18),
#   Row(StudentID='S1026', Name='Brenda White', OverdueCount=5),
#   Row(StudentID='S1065', Name='Guy Molina', OverdueCount=15),
#   Row(StudentID='S1041', Name='Jacob Tran', OverdueCount=24),
#   Row(StudentID='S1011', Name='Deborah Richards', OverdueCount=9),
#   Row(StudentID='S1047', Name='Martin Ross', OverdueCount=24),
#   Row(StudentID='S1040', Name='Jessica Smith', OverdueCount=16),
#   Row(StudentID='S1062', Name='Denise Jones', OverdueCount=11),
#   Row(StudentID='S1044', Name='Sierra Johnson', OverdueCount=9),
#   Row(StudentID='S1008', Name='James Mayo', OverdueCount=12)]}

# %%
#Save dataframe to gold table
overdue_df.write.format("delta").mode("overwrite").saveAsTable("GoldLakehouse.gold_Overdue")
# Out:
# StatementMeta(, 182160f5-f81d-487b-aeae-4a71abfb9635, 19, Finished, Available, Finished)
